# %%
import pandas as pd

# %%
df = pd.read_excel('saleslistasoj.xlsx')

# %%
df.head(20)
# Out:
#    Bhole Baba Order Suppliers   Unnamed: 1                Unnamed: 2  \
# 0      List of Sales Vouchers          NaN                       NaN
# 1       Voucher Series : Main          NaN                       NaN
# 2                        Date  Vch/Bill No               Particulars
# 3                 01-06-2078           373   Dipak & Nabin Suppliers
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                 01-06-2078           374   Dipak & Nabin Suppliers
# 10                        NaN
# 11                        NaN
# 12                01-06-2078           375  Bijayeswori  Bhada Pasal
# 13                        NaN
# 14                01-06-2078           376  Bijayeswori  Bhada Pasal
# 15                01-06-2078           377        Sunita Fancy Store
# 16                        NaN
# 17                        NaN
# 18                        NaN
# ...

# %%
### Renaming columns properly
df_new = df.rename(columns={'Unnamed: 1': 'Vch/Bill No', 'Unnamed: 2': 'Particulars', 'Unnamed: 3': 'Item Details',  'Unnamed: 4': 'Qty', 'Unnamed: 5': 'Unit'})
df_new = df_new[3:]
df_new
# Out:
#     Bhole Baba Order Suppliers Vch/Bill No              Particulars  \
# 3                  01-06-2078          373  Dipak & Nabin Suppliers
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# ..                         ...         ...                      ...
# 978                31-06-2078          631   Dip Jyoti Kirana Pasal
# 979                        NaN
# 980                        NaN
# 981                        NaN         NaN                      NaN
# 982                        NaN         NaN                      NaN
#
#                                  Item Details    Qty    Unit
# 3    Swastik RefineSoyabean Oil 1/2 Ltr Pouch     50  Carton
# 4                                 Suji 1/2*40      5    Sack
# 5                               Soap Amar 300     25  Carton
# 6                                   Atta 5kgs     50    Sack
# ...

# %%
# Data cleaning

df_new.to_excel('formattedData.xlsx', index=False)

# %%
#reading the df from new file
#converting to proper datatypes
#df = pd.read_excel('formattedData.xlsx', dtype = {'Item Details': 'string', 'Qty': 'float', 'Unit': 'string', 'Vch/Bill No': 'float' })
df['Vch/Bill No'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2052/2983884541.py in <module>
#       2 #converting to proper datatypes
#       3 #df = pd.read_excel('formattedData.xlsx', dtype = {'Item Details': 'string', 'Qty': 'float', 'Unit': 'string', 'Vch/Bill No': 'float' })
# ----> 4 df['Vch/Bill No'].astype('int')
#
# c:\users\ayusman\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ...

# %%
df.groupby('Particulars', 'Vch/Bill No').sum('Qty')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\ayusman\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     545         try:
# --> 546             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547         except KeyError:
#
# KeyError: 'Vch/Bill No'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2052/4196256961.py in <module>
# ----> 1 df.groupby('Particulars', 'Vch/Bill No').sum('Qty')
#
# c:\users\ayusman\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7625         if level is None and by is None:
# ...
